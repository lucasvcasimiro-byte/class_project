# %% [markdown]
# ## Data Exploration

# %%
import pandas as pd

usage= pd.read_csv("Smartphone_Usage_Productivity_Dataset_50000.csv", index_col=0)
usage.head()
# Out:
#          Age  Gender      Occupation Device_Type  Daily_Phone_Hours  \
# User_ID
# U1        58    Male    Professional     Android                1.3
# U2        25    Male    Professional     Android                1.2
# U3        19    Male         Student         iOS                5.3
# U4        35  Female  Business Owner         iOS                5.8
# U5        33    Male      Freelancer     Android                7.9
#
#          Social_Media_Hours  Work_Productivity_Score  Sleep_Hours  \
# User_ID
# U1                      6.7                        6          8.8
# U2                      1.5                        5          6.4
# U3                      5.7                        5          9.0
# U4                      2.5                        2          5.7
# U5                      1.3                        4          5.7
#
#          Stress_Level  App_Usage_Count  Caffeine_Intake_Cups  \
# User_ID
# U1                  4               42                     1
# ...

# %%
usage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50000 entries, U1 to U50000
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Age                        50000 non-null  int64
#  1   Gender                     50000 non-null  object
#  2   Occupation                 50000 non-null  object
#  3   Device_Type                50000 non-null  object
#  4   Daily_Phone_Hours          50000 non-null  float64
#  5   Social_Media_Hours         50000 non-null  float64
#  6   Work_Productivity_Score    50000 non-null  int64
#  7   Sleep_Hours                50000 non-null  float64
#  8   Stress_Level               50000 non-null  int64
#  9   App_Usage_Count            50000 non-null  int64
#  10  Caffeine_Intake_Cups       50000 non-null  int64
#  11  Weekend_Screen_Time_Hours  50000 non-null  float64
# dtypes: float64(4), int64(5), object(3)
# memory usage: 5.0+ MB
